# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

import matplotlib.pyplot as plt

# %%
def new_gelu(x):
    return 0.5 * x * (1.0 + torch.tanh(np.sqrt(2.0 / np.pi) * (x + 0.044715 * torch.pow(x, 3.0))))

# %%
fig,ax = plt.subplots(figsize=(6,4))

x = torch.linspace(-5,5,1000)

ax.plot(x,new_gelu(x),"-",label="new GELU")

ax.legend()
ax.grid()
plt.show()

# %%
n_emb = 3

l = nn.Linear(n_emb,3*n_emb,bias=True)
l(torch.eye(n_emb))
# Out:
# tensor([[ 0.0271,  0.0784, -0.0311,  ...,  0.1237, -0.0171, -0.1327],
#         [-0.0287, -0.0704, -0.1897,  ..., -0.0010,  0.1270, -0.0868],
#         [-0.2415,  0.2020, -0.1684,  ...,  0.0191, -0.0549, -0.0479],
#         ...,
#         [-0.1527, -0.0040, -0.0082,  ..., -0.0913,  0.2304, -0.2441],
#         [-0.1167, -0.1106, -0.3373,  ...,  0.1542,  0.0473, -0.0527],
#         [ 0.0203, -0.0994, -0.1272,  ...,  0.0662,  0.2033, -0.1144]],
#        grad_fn=<AddmmBackward0>)

# %%
torch.eye(3)
# Out:
# tensor([[1., 0., 0.],
#         [0., 1., 0.],
#         [0., 0., 1.]])
